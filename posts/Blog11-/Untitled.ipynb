# %% [raw]
# ---
# title: "Is GPT more empathetic when speaking Chinese?"
# description: "Cultural differences embedded in the training data influence the LLM’s communicative style"
# author: "Florrie"
# date: "10/04/2025"
# categories:
#   - Culture
#   - Communication
# ---

# %% [markdown]
# ![AI showing empathy](empathy.png)
